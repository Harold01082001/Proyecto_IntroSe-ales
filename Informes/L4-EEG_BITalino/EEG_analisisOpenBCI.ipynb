# %% [markdown]
# # Lectura y graficación de una señal almacenada en un archivo txt

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Generamos un periodo y una frecuencia de muestreo

# %%
Fs = 1000
Ts=1/Fs

print(f" Fs={Fs} hz\n Ts={Ts} s")
# Out:
#  Fs=1000 hz
#  Ts=0.001 s

# %% [markdown]
# ## Leemos los 5 archivos con los canales a analizar

# %%
array_1 = np.genfromtxt("EXG_Channel_2.txt", delimiter="\t",skip_header = 4)
array_2=  np.genfromtxt("EXG_Channel_3.txt", delimiter="\t",skip_header = 4)
array_3= np.genfromtxt("EXG_Channel_5.txt", delimiter="\t",skip_header = 4)
array_4= np.genfromtxt("EXG_Channel_6.txt", delimiter="\t",skip_header = 4)
array_5= np.genfromtxt("EXG_Channel_8.txt", delimiter="\t",skip_header = 4)

# %% [markdown]
# ## Ploteamos la lectura

# %%
# Supongamos que el DataFrame se llama 'df' y las señales EEG están en las columnas 1 a n
muestras.iloc[:, 1:].plot(figsize=(10, 6))  # grafica todas las columnas excepto la primera
plt.xlabel('Muestras')
plt.ylabel('Amplitud')
plt.title('Señales EEG')
plt.show()

# %%
#Momento de reposo inicial
plt.plot(array_1, label="señal")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("N° de muestras (n)")
plt.ylabel("Amplitud")
plt.title("Channel 2")
plt.legend(loc="upper right")
#plt.xlim([5500,6000])

plt.show()

# %%
plt.plot(array_2, label="señal")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("N° de muestras (n)")
plt.ylabel("Amplitud")
plt.title("Chanel 3")

plt.legend(loc="upper right")
plt.xlim([5000,6000])

plt.show()

# %%
plt.plot(array_3, label="señal")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("N° de muestras (n)")
plt.ylabel("Amplitud")
plt.title("Channel 5")
plt.legend(loc="upper right")
plt.xlim([3000,4000])

plt.show()

# %%
plt.plot(array_4, label="señal")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("N° de muestras (n)")
plt.ylabel("Amplitud")
plt.title("Channel 6")
plt.legend(loc="upper right")
plt.xlim([3000,3500])


plt.show()

# %%
plt.plot(array_5, label="señal")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("N° de muestras (n)")
plt.ylabel("Amplitud")
plt.title("Channel 8")
plt.legend(loc="upper right")
plt.xlim([3200,4000])


plt.show()

# %%
n=np.arange(0,len(array_1))
t_continuo=n*Ts
print(t_continuo)

#Plot de la señal continua

plt.plot(t_continuo,array_1, label="señal continua")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("tiempo (s)")
plt.ylabel("Amplitud")
plt.title("Channel 2")
plt.legend(loc="upper right")
#plt.xlim([55,74])
plt.show()
# Out:
# [0.0000e+00 1.0000e-03 2.0000e-03 ... 3.9403e+01 3.9404e+01 3.9405e+01]

# %%
n=np.arange(0,len(array_2))
t_continuo=n*Ts
print(t_continuo)

#Plot de la señal continua

plt.plot(t_continuo,array_2, label="señal continua")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("tiempo (s)")
plt.ylabel("Amplitud")
plt.title("Channel 3")
plt.legend(loc="upper right")
#plt.xlim([55,74])
plt.show()
# Out:
# [0.0000e+00 1.0000e-03 2.0000e-03 ... 3.9403e+01 3.9404e+01 3.9405e+01]

# %%
n=np.arange(0,len(array_3))
t_continuo=n*Ts
print(t_continuo)

#Plot de la señal continua

plt.plot(t_continuo,array_3, label="señal continua")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("tiempo (s)")
plt.ylabel("Amplitud")
plt.title("Channel 5")
plt.legend(loc="upper right")
#plt.xlim([55,74])
plt.show()
# Out:
# [0.0000e+00 1.0000e-03 2.0000e-03 ... 3.9403e+01 3.9404e+01 3.9405e+01]

# %%
n=np.arange(0,len(array_4))
t_continuo=n*Ts
print(t_continuo)

#Plot de la señal continua

plt.plot(t_continuo,array_4, label="señal continua")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("tiempo (s)")
plt.ylabel("Amplitud")
plt.title("Channel 6")
plt.legend(loc="upper right")
#plt.xlim([55,74])
plt.show()
# Out:
# [0.0000e+00 1.0000e-03 2.0000e-03 ... 3.9403e+01 3.9404e+01 3.9405e+01]

# %%
n=np.arange(0,len(array_5))
t_continuo=n*Ts
print(t_continuo)

#Plot de la señal continua

plt.plot(t_continuo,array_5, label="señal continua")      # graficamos la señal
plt.grid(linestyle=":")
plt.xlabel("tiempo (s)")
plt.ylabel("Amplitud")
plt.title("Channel 8")
plt.legend(loc="upper right")
#plt.xlim([55,74])
plt.show()
# Out:
# [0.0000e+00 1.0000e-03 2.0000e-03 ... 3.9403e+01 3.9404e+01 3.9405e+01]

# %% [markdown]
# ## La forma de saber la frecuencia de la señal es viendo en el dominio de la frecuencia

# %%
N = 2**10                                     # 10 bits, 0-1023

signal1 = array_1

signal_fft = np.fft.fft(signal1, N)           # fft magtinud
signal_fft = np.round(np.abs(signal_fft),3)[0:N//2] # nos quedamos con los componente de la derecha de la FFT
signal_aux = signal_fft/signal_fft.max()     # hallamos el maximo para pasar la magnitud a escala db

with np.errstate(divide='ignore'):
    signal_fft_db = 10*np.log10(signal_aux)  # , out=signal_aux, where=signal_aux >= 0 para evitar division por zero

F_list = np.linspace(0,Fs/2, N//2)
F = np.round(F_list[np.argmax(signal_fft_db)], 1)   # argmax, encuentra el argumento max en un array

plt.plot(F_list, signal_fft_db)  #10 * np.log10(P / Pref) , decibelios
plt.text(F,0, f"{F}Hz")
plt.grid(linestyle=":")
plt.ylabel("Magnitud (db)")
plt.xlabel("Frecuencias (Hz)")
plt.title("Channel 2")
plt.xlim([0,200])
plt.xticks(np.arange(0,200,10))
plt.show()

# %%
N = 2**10                                     # 10 bits, 0-1023

signal1 = array_2

signal_fft = np.fft.fft(signal1, N)           # fft magtinud
signal_fft = np.round(np.abs(signal_fft),3)[0:N//2] # nos quedamos con los componente de la derecha de la FFT
signal_aux = signal_fft/signal_fft.max()     # hallamos el maximo para pasar la magnitud a escala db

with np.errstate(divide='ignore'):
    signal_fft_db = 10*np.log10(signal_aux)  # , out=signal_aux, where=signal_aux >= 0 para evitar division por zero

F_list = np.linspace(0,Fs/2, N//2)
F = np.round(F_list[np.argmax(signal_fft_db)], 1)   # argmax, encuentra el argumento max en un array

plt.plot(F_list, signal_fft_db)  #10 * np.log10(P / Pref) , decibelios
plt.text(F,0, f"{F}Hz")
plt.grid(linestyle=":")
plt.ylabel("Magnitud (db)")
plt.xlabel("Frecuencias (Hz)")
plt.title("Channel 3")
plt.xlim([0,200])
plt.xticks(np.arange(0,200,10))
plt.show()

# %%
N = 2**10                                     # 10 bits, 0-1023

signal1 = array_3

signal_fft = np.fft.fft(signal1, N)           # fft magtinud
signal_fft = np.round(np.abs(signal_fft),3)[0:N//2] # nos quedamos con los componente de la derecha de la FFT
signal_aux = signal_fft/signal_fft.max()     # hallamos el maximo para pasar la magnitud a escala db

with np.errstate(divide='ignore'):
    signal_fft_db = 10*np.log10(signal_aux)  # , out=signal_aux, where=signal_aux >= 0 para evitar division por zero

F_list = np.linspace(0,Fs/2, N//2)
F = np.round(F_list[np.argmax(signal_fft_db)], 1)   # argmax, encuentra el argumento max en un array

plt.plot(F_list, signal_fft_db)  #10 * np.log10(P / Pref) , decibelios
plt.text(F,0, f"{F}Hz")
plt.grid(linestyle=":")
plt.ylabel("Magnitud (db)")
plt.xlabel("Frecuencias (Hz)")
plt.title("Channel 5")
plt.xlim([0,200])
plt.xticks(np.arange(0,200,10))
plt.show()

# %%
N = 2**10                                     # 10 bits, 0-1023

signal1 = array_4

signal_fft = np.fft.fft(signal1, N)           # fft magtinud
signal_fft = np.round(np.abs(signal_fft),3)[0:N//2] # nos quedamos con los componente de la derecha de la FFT
signal_aux = signal_fft/signal_fft.max()     # hallamos el maximo para pasar la magnitud a escala db

with np.errstate(divide='ignore'):
    signal_fft_db = 10*np.log10(signal_aux)  # , out=signal_aux, where=signal_aux >= 0 para evitar division por zero

F_list = np.linspace(0,Fs/2, N//2)
F = np.round(F_list[np.argmax(signal_fft_db)], 1)   # argmax, encuentra el argumento max en un array

plt.plot(F_list, signal_fft_db)  #10 * np.log10(P / Pref) , decibelios
plt.text(F,0, f"{F}Hz")
plt.grid(linestyle=":")
plt.ylabel("Magnitud (db)")
plt.xlabel("Frecuencias (Hz)")
plt.title("Channel 6")
plt.xlim([0,200])
plt.xticks(np.arange(0,200,10))
plt.show()

# %%
N = 2**10                                     # 10 bits, 0-1023

signal1 = array_5

signal_fft = np.fft.fft(signal1, N)           # fft magtinud
signal_fft = np.round(np.abs(signal_fft),3)[0:N//2] # nos quedamos con los componente de la derecha de la FFT
signal_aux = signal_fft/signal_fft.max()     # hallamos el maximo para pasar la magnitud a escala db

with np.errstate(divide='ignore'):
    signal_fft_db = 10*np.log10(signal_aux)  # , out=signal_aux, where=signal_aux >= 0 para evitar division por zero

F_list = np.linspace(0,Fs/2, N//2)
F = np.round(F_list[np.argmax(signal_fft_db)], 1)   # argmax, encuentra el argumento max en un array

plt.plot(F_list, signal_fft_db)  #10 * np.log10(P / Pref) , decibelios
plt.text(F,0, f"{F}Hz")
plt.grid(linestyle=":")
plt.ylabel("Magnitud (db)")
plt.xlabel("Frecuencias (Hz)")
plt.title("Channel 8")
plt.xlim([0,200])
plt.xticks(np.arange(0,200,10))
plt.show()
